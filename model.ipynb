# %%
# import keras
# import gzip
# import numpy as np
# import matplotlib.pyplot as plt
# from sklearn.model_selection import train_test_split
# import tensorflow as tf
# from tensorflow.keras.models import Sequential
# from tensorflow.keras.layers import Conv2D, MaxPooling2D, Flatten, Dense, Input

# def load_images(file_path):
#     with gzip.open(file_path, 'rb') as f:
#         f.read(16)  
#         buffer = f.read()
#         data = np.frombuffer(buffer, dtype=np.uint8)
#         return data.reshape(-1, 28, 28)

# def load_labels(file_path):
#     with gzip.open(file_path, 'rb') as f:
#         f.read(8)  
#         buffer = f.read()
#         return np.frombuffer(buffer, dtype=np.uint8)

# def load_mapping(mapping_file_path):
#     mapping = {}
#     with open(mapping_file_path, 'r') as f:
#         for line in f:
#             label, char_code = line.strip().split()
#             mapping[int(label)] = chr(int(char_code))
#     return mapping

# mapping_file = "C:\\Users\\dpand\\Desktop\\New folder\\gzip\\emnist-byclass-mapping.txt"
# label_to_char = load_mapping(mapping_file)

# print("Label 1 corresponds to:", label_to_char[1])

# train_images = load_images("C:\\Users\\dpand\\Desktop\\New folder\\gzip\\emnist-byclass-train-images-idx3-ubyte.gz")
# train_labels = load_labels("C:\\Users\\dpand\\Desktop\\New folder\\gzip\\emnist-byclass-train-labels-idx1-ubyte.gz")

# print("Train images shape:", train_images.shape)
# print("Train labels shape:", train_labels.shape)

# train_images = train_images / 255.0

# X_train, X_val, y_train, y_val = train_test_split(train_images, train_labels, test_size=0.2, random_state=42)
# X_train = X_train.reshape(-1, 28, 28, 1)
# X_val = X_val.reshape(-1, 28, 28, 1)

# model = Sequential([
#     Input(shape=(28, 28, 1)),
#     Conv2D(32, (3, 3), activation='relu'),
#     MaxPooling2D((2, 2)),
#     Conv2D(64, (3, 3), activation='relu'),
#     MaxPooling2D((2, 2)),
#     Flatten(),
#     Dense(128, activation='relu'),
#     Dense(len(label_to_char), activation='softmax')
# ])

# model.compile(optimizer='adam', loss='sparse_categorical_crossentropy', metrics=['accuracy'])

# train = model.fit(X_train, y_train, epochs=10, batch_size=32, validation_data=(X_val, y_val), verbose=1)

# test_loss, test_accuracy = model.evaluate(X_val, y_val)
# with open("output_log.txt", "w", encoding="utf-8") as f:
#     f.write(f"Validation Accuracy = {test_accuracy * 100:.2f}%\n")

# # Plot training & validation accuracy and loss
# plt.figure(figsize=(12, 4))
# plt.subplot(1, 2, 1)
# plt.plot(train.history['accuracy'], label='Train Accuracy')
# plt.plot(train.history['val_accuracy'], label='Validation Accuracy')
# plt.xlabel('Epoch')
# plt.ylabel('Accuracy')
# plt.legend()
# plt.title('Model Accuracy')

# plt.subplot(1, 2, 2)
# plt.plot(train.history['loss'], label='Train Loss')
# plt.plot(train.history['val_loss'], label='Validation Loss')
# plt.xlabel('Epoch')
# plt.ylabel('Loss')
# plt.legend()
# plt.title('Model Loss')

# plt.show()
# Out:
# Label 1 corresponds to: 1
# Train images shape: (697932, 28, 28)
# Train labels shape: (697932,)
# Epoch 1/10
# 17449/17449 ━━━━━━━━━━━━━━━━━━━━ 92s 5ms/step - accuracy: 0.7893 - loss: 0.6667 - val_accuracy: 0.8569 - val_loss: 0.4000
# Epoch 2/10
# 17449/17449 ━━━━━━━━━━━━━━━━━━━━ 86s 5ms/step - accuracy: 0.8582 - loss: 0.3872 - val_accuracy: 0.8600 - val_loss: 0.3838
# Epoch 3/10
# 17449/17449 ━━━━━━━━━━━━━━━━━━━━ 100s 6ms/step - accuracy: 0.8659 - loss: 0.3588 - val_accuracy: 0.8625 - val_loss: 0.3785
# Epoch 4/10
# 17449/17449 ━━━━━━━━━━━━━━━━━━━━ 97s 6ms/step - accuracy: 0.8709 - loss: 0.3414 - val_accuracy: 0.8635 - val_loss: 0.3743
# Epoch 5/10
# 17449/17449 ━━━━━━━━━━━━━━━━━━━━ 97s 6ms/step - accuracy: 0.8742 - loss: 0.3298 - val_accuracy: 0.8632 - val_loss: 0.3797
# Epoch 6/10
# 17449/17449 ━━━━━━━━━━━━━━━━━━━━ 94s 5ms/step - accuracy: 0.8768 - loss: 0.3206 - val_accuracy: 0.8640 - val_loss: 0.3803
# Epoch 7/10
# ...

# %%
# import keras
# import gzip
# import numpy as np
# import matplotlib.pyplot as plt
# from sklearn.model_selection import train_test_split
# import tensorflow as tf
# from tensorflow.keras.models import Sequential
# from tensorflow.keras.layers import Conv2D, MaxPooling2D, Flatten, Dense, Input, Dropout
# from tensorflow.keras.preprocessing.image import ImageDataGenerator
# from tensorflow.keras.callbacks import ReduceOnPlateau
# def load_images(file_path):
#     with gzip.open(file_path, 'rb') as f:
#         f.read(16)  
#         buffer = f.read()
#         data = np.frombuffer(buffer, dtype=np.uint8)
#         return data.reshape(-1, 28, 28)

# def load_labels(file_path):
#     with gzip.open(file_path, 'rb') as f:
#         f.read(8)  
#         buffer = f.read()
#         return np.frombuffer(buffer, dtype=np.uint8)

# def load_mapping(mapping_file_path):
#     mapping = {}
#     with open(mapping_file_path, 'r') as f:
#         for line in f:
#             label, char_code = line.strip().split()
#             mapping[int(label)] = chr(int(char_code))
#     return mapping

# mapping_file = "C:\\Users\\dpand\\Desktop\\New folder\\gzip\\emnist-byclass-mapping.txt"
# label_to_char = load_mapping(mapping_file)

# print("Label 1 corresponds to:", label_to_char[1])

# train_images = load_images("C:\\Users\\dpand\\Desktop\\New folder\\gzip\\emnist-byclass-train-images-idx3-ubyte.gz")
# train_labels = load_labels("C:\\Users\\dpand\\Desktop\\New folder\\gzip\\emnist-byclass-train-labels-idx1-ubyte.gz")

# print("Train images shape:", train_images.shape)
# print("Train labels shape:", train_labels.shape)

# train_images = train_images / 255.0

# X_train, X_val, y_train, y_val = train_test_split(train_images, train_labels, test_size=0.2, random_state=42)
# X_train = X_train.reshape(-1, 28, 28, 1)
# X_val = X_val.reshape(-1, 28, 28, 1)



# model = Sequential([
#     Input(shape=(28, 28, 1)),
#     Conv2D(32, (3, 3), activation='relu'),
#     MaxPooling2D((2, 2)),
#     Conv2D(64, (3, 3), activation='relu'),
#     MaxPooling2D((2, 2)),
#     Flatten(),
#     Dense(64, activation='relu'),
#     Dropout(0.5),
#     Dense(len(label_to_char), activation='softmax')
# ])

# model.compile(optimizer='adam', loss='sparse_categorical_crossentropy', metrics=['accuracy'])

# train = model.fit(X_train, y_train, epochs=10, batch_size=32, validation_data=(X_val, y_val), verbose=1)

# test_loss, test_accuracy = model.evaluate(X_val, y_val)
# with open("output_log.txt", "w", encoding="utf-8") as f:
#     f.write(f"Validation Accuracy = {test_accuracy * 100:.2f}%\n")

# # Plot training & validation accuracy and loss
# plt.figure(figsize=(12, 4))
# plt.subplot(1, 2, 1)
# plt.plot(train.history['accuracy'], label='Train Accuracy')
# plt.plot(train.history['val_accuracy'], label='Validation Accuracy')
# plt.xlabel('Epoch')
# plt.ylabel('Accuracy')
# plt.legend()
# plt.title('Model Accuracy')

# plt.subplot(1, 2, 2)
# plt.plot(train.history['loss'], label='Train Loss')
# plt.plot(train.history['val_loss'], label='Validation Loss')
# plt.xlabel('Epoch')
# plt.ylabel('Loss')
# plt.legend()
# plt.title('Model Loss')

# plt.show()
# Out:
# Label 1 corresponds to: 1
# Train images shape: (697932, 28, 28)
# Train labels shape: (697932,)
# Epoch 1/10
# 17449/17449 ━━━━━━━━━━━━━━━━━━━━ 143s 8ms/step - accuracy: 0.6478 - loss: 1.2217 - val_accuracy: 0.8339 - val_loss: 0.4603
# Epoch 2/10
# 17449/17449 ━━━━━━━━━━━━━━━━━━━━ 140s 8ms/step - accuracy: 0.7854 - loss: 0.6556 - val_accuracy: 0.8481 - val_loss: 0.4313
# Epoch 3/10
# 17449/17449 ━━━━━━━━━━━━━━━━━━━━ 140s 8ms/step - accuracy: 0.8014 - loss: 0.6004 - val_accuracy: 0.8491 - val_loss: 0.4260
# Epoch 4/10
# 17449/17449 ━━━━━━━━━━━━━━━━━━━━ 141s 8ms/step - accuracy: 0.8095 - loss: 0.5759 - val_accuracy: 0.8520 - val_loss: 0.4190
# Epoch 5/10
# 17449/17449 ━━━━━━━━━━━━━━━━━━━━ 135s 8ms/step - accuracy: 0.8135 - loss: 0.5602 - val_accuracy: 0.8496 - val_loss: 0.4260
# Epoch 6/10
# 17449/17449 ━━━━━━━━━━━━━━━━━━━━ 142s 8ms/step - accuracy: 0.8165 - loss: 0.5470 - val_accuracy: 0.8535 - val_loss: 0.4148
# Epoch 7/10
# ...

# %%
# import keras
# import gzip
# import numpy as np
# import matplotlib.pyplot as plt
# from sklearn.model_selection import train_test_split
# import tensorflow as tf
# from tensorflow.keras.models import Sequential
# from tensorflow.keras.layers import Conv2D, MaxPooling2D, Flatten, Dense, Input, Dropout
# from tensorflow.keras.preprocessing.image import ImageDataGenerator
# from tensorflow.keras.callbacks import ReduceLROnPlateau
# def load_images(file_path):
#     with gzip.open(file_path, 'rb') as f:
#         f.read(16)  
#         buffer = f.read()
#         data = np.frombuffer(buffer, dtype=np.uint8)
#         return data.reshape(-1, 28, 28)

# def load_labels(file_path):
#     with gzip.open(file_path, 'rb') as f:
#         f.read(8)  
#         buffer = f.read()
#         return np.frombuffer(buffer, dtype=np.uint8)

# def load_mapping(mapping_file_path):
#     mapping = {}
#     with open(mapping_file_path, 'r') as f:
#         for line in f:
#             label, char_code = line.strip().split()
#             mapping[int(label)] = chr(int(char_code))
#     return mapping

# mapping_file = "C:\\Users\\dpand\\Desktop\\New folder\\gzip\\emnist-byclass-mapping.txt"
# label_to_char = load_mapping(mapping_file)

# print("Label 1 corresponds to:", label_to_char[1])

# train_images = load_images("C:\\Users\\dpand\\Desktop\\New folder\\gzip\\emnist-byclass-train-images-idx3-ubyte.gz")
# train_labels = load_labels("C:\\Users\\dpand\\Desktop\\New folder\\gzip\\emnist-byclass-train-labels-idx1-ubyte.gz")

# print("Train images shape:", train_images.shape)
# print("Train labels shape:", train_labels.shape)

# train_images = train_images / 255.0

# X_train, X_val, y_train, y_val = train_test_split(train_images, train_labels, test_size=0.2, random_state=42)
# X_train = X_train.reshape(-1, 28, 28, 1)
# X_val = X_val.reshape(-1, 28, 28, 1)

# #Data Augmentation
# datagen = ImageDataGenerator(
#     rotation_range = 10,
#     width_shift_range = 0.1,
#     height_shift_range = 0.1,
#     horizontal_flip = False
# )

# datagen.fit(X_train)

# #Reduce learning rate on shedule if the val_loss stays same
# reduce_lr = ReduceLROnPlateau(monitor = 'val_loss',factor = 0.2, patience = 2, min_lr= 0.001)

# model = Sequential([
#     Input(shape=(28, 28, 1)),
#     Conv2D(32, (3, 3), activation='relu'),
#     MaxPooling2D((2, 2)),
#     Conv2D(64, (3, 3), activation='relu'),
#     MaxPooling2D((2, 2)),
#     Flatten(),
#     Dense(64, activation='relu'),
#     Dropout(0.5),
#     Dense(len(label_to_char), activation='softmax')
# ])

# model.compile(optimizer='adam', loss='sparse_categorical_crossentropy', metrics=['accuracy'])

# train = model.fit( datagen.flow(X_train,y_train,batch_size = 32),epochs=10, validation_data=(X_val, y_val),callbacks = [reduce_lr], verbose=1)

# test_loss, test_accuracy = model.evaluate(X_val, y_val)
# with open("output_log.txt", "w", encoding="utf-8") as f:
#     f.write(f"Validation Accuracy = {test_accuracy * 100:.2f}%\n")

# # Plot training & validation accuracy and loss
# plt.figure(figsize=(12, 4))
# plt.subplot(1, 2, 1)
# plt.plot(train.history['accuracy'], label='Train Accuracy')
# plt.plot(train.history['val_accuracy'], label='Validation Accuracy')
# plt.xlabel('Epoch')
# plt.ylabel('Accuracy')
# plt.legend()
# plt.title('Model Accuracy')

# plt.subplot(1, 2, 2)
# plt.plot(train.history['loss'], label='Train Loss')
# plt.plot(train.history['val_loss'], label='Validation Loss')
# plt.xlabel('Epoch')
# plt.ylabel('Loss')
# plt.legend()
# plt.title('Model Loss')

# plt.show()

# %%
import keras
import gzip
import numpy as np
import matplotlib.pyplot as plt
from sklearn.model_selection import train_test_split
import tensorflow as tf
from tensorflow.keras.models import Sequential
from tensorflow.keras.layers import Conv2D, MaxPooling2D, Flatten, Dense, Input, Dropout
from tensorflow.keras.preprocessing.image import ImageDataGenerator
from tensorflow.keras.callbacks import ReduceLROnPlateau
def load_images(file_path):
    with gzip.open(file_path, 'rb') as f:
        f.read(16)  
        buffer = f.read()
        data = np.frombuffer(buffer, dtype=np.uint8)
        return data.reshape(-1, 28, 28)

def load_labels(file_path):
    with gzip.open(file_path, 'rb') as f:
        f.read(8)  
        buffer = f.read()
        return np.frombuffer(buffer, dtype=np.uint8)

def load_mapping(mapping_file_path):
    mapping = {}
    with open(mapping_file_path, 'r') as f:
        for line in f:
            label, char_code = line.strip().split()
            mapping[int(label)] = chr(int(char_code))
    return mapping

mapping_file = "C:\\Users\\dpand\\Desktop\\New folder\\gzip\\emnist-byclass-mapping.txt"
label_to_char = load_mapping(mapping_file)

print("Label 1 corresponds to:", label_to_char[1])

train_images = load_images("C:\\Users\\dpand\\Desktop\\New folder\\gzip\\emnist-byclass-train-images-idx3-ubyte.gz")
train_labels = load_labels("C:\\Users\\dpand\\Desktop\\New folder\\gzip\\emnist-byclass-train-labels-idx1-ubyte.gz")

print("Train images shape:", train_images.shape)
print("Train labels shape:", train_labels.shape)

train_images = train_images / 255.0

X_train, X_val, y_train, y_val = train_test_split(train_images, train_labels, test_size=0.2, random_state=42)
X_train = X_train.reshape(-1, 28, 28, 1)
X_val = X_val.reshape(-1, 28, 28, 1)

#Data Augmentation
datagen = ImageDataGenerator(
    rotation_range = 10,
    width_shift_range = 0.1,
    height_shift_range = 0.1,
    horizontal_flip = False
)

datagen.fit(X_train)

#Reduce learning rate on shedule if the val_loss stays same
reduce_lr = ReduceLROnPlateau(monitor = 'val_loss',factor = 0.2, patience = 2, min_lr= 0.001)

model = Sequential([
    Input(shape=(28, 28, 1)),
    Conv2D(32, (3, 3), activation='relu'),
    MaxPooling2D((2, 2)),
    Conv2D(64, (3, 3), activation='relu'),
    MaxPooling2D((2, 2)),
    Flatten(),
    Dense(64, activation='relu'),
    Dropout(0.3),
    Dense(len(label_to_char), activation='softmax')
])

model.compile(optimizer='adam', loss='sparse_categorical_crossentropy', metrics=['accuracy'])

train = model.fit( datagen.flow(X_train,y_train,batch_size = 32),epochs=10, validation_data=(X_val, y_val),callbacks = [reduce_lr], verbose=1)

test_loss, test_accuracy = model.evaluate(X_val, y_val)
with open("output_log.txt", "w", encoding="utf-8") as f:
    f.write(f"Validation Accuracy = {test_accuracy * 100:.2f}%\n")

# Plot training & validation accuracy and loss
plt.figure(figsize=(12, 4))
plt.subplot(1, 2, 1)
plt.plot(train.history['accuracy'], label='Train Accuracy')
plt.plot(train.history['val_accuracy'], label='Validation Accuracy')
plt.xlabel('Epoch')
plt.ylabel('Accuracy')
plt.legend()
plt.title('Model Accuracy')

plt.subplot(1, 2, 2)
plt.plot(train.history['loss'], label='Train Loss')
plt.plot(train.history['val_loss'], label='Validation Loss')
plt.xlabel('Epoch')
plt.ylabel('Loss')
plt.legend()
plt.title('Model Loss')

plt.show()
# Out:
# Label 1 corresponds to: 1
# Train images shape: (697932, 28, 28)
# Train labels shape: (697932,)
# C:\Users\dpand\anaconda3\Lib\site-packages\keras\src\trainers\data_adapters\py_dataset_adapter.py:121: UserWarning: Your `PyDataset` class should call `super().__init__(**kwargs)` in its constructor. `**kwargs` can include `workers`, `use_multiprocessing`, `max_queue_size`. Do not pass these arguments to `fit()`, as they will be ignored.
#   self._warn_if_super_not_called()
# Epoch 1/10
# 17449/17449 ━━━━━━━━━━━━━━━━━━━━ 364s 21ms/step - accuracy: 0.6597 - loss: 1.1785 - val_accuracy: 0.8335 - val_loss: 0.4769 - learning_rate: 0.0010
# Epoch 2/10
# 17449/17449 ━━━━━━━━━━━━━━━━━━━━ 358s 21ms/step - accuracy: 0.7899 - loss: 0.6325 - val_accuracy: 0.8441 - val_loss: 0.4369 - learning_rate: 0.0010
# Epoch 3/10
# 17449/17449 ━━━━━━━━━━━━━━━━━━━━ 195s 11ms/step - accuracy: 0.8052 - loss: 0.5826 - val_accuracy: 0.8471 - val_loss: 0.4399 - learning_rate: 0.0010
# Epoch 4/10
# ...

# %% [markdown]
# #Saving Model

# %%
# Save the entire model

model.save('cnn_model.h5')
print("Model Saved")
loaded_model = load_model('cnn_model.h5')
loaded_model.summary()
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# Cell In[5], line 2
#       1 # Save the entire model
# ----> 2 model.save('cnn_model.h5')
#       3 print("Model Saved")
#       4 loaded_model = load_model('cnn_model.h5')
#
# NameError: name 'model' is not defined

# %% [markdown]
# Creating GAN (Defining Generator and Discriminator)

# %%
import keras
import gzip
import tensorflow as tf
import numpy as np
import matplotlib.pyplot as plt
from sklearn.model_selection import train_test_split
import tensorflow as tf
from tensorflow.keras.preprocessing.image import ImageDataGenerator
from tensorflow.keras.layers import Input, Dense, Reshape, Flatten, Dropout, LeakyReLU, Conv2D, Conv2DTranspose, UpSampling2D, BatchNormalization, Embedding, multiply, Concatenate
from tensorflow.keras.models import Sequential, Model

# Helper Functions to Load EMNIST Data
def load_images(file_path):
    with gzip.open(file_path, 'rb') as f:
        f.read(16)  
        buffer = f.read()
        data = np.frombuffer(buffer, dtype=np.uint8)
        return data.reshape(-1, 28, 28)

def load_labels(file_path):
    with gzip.open(file_path, 'rb') as f:
        f.read(8)  
        buffer = f.read()
        return np.frombuffer(buffer, dtype=np.uint8)

def load_mapping(mapping_file_path):
    mapping = {}
    with open(mapping_file_path, 'r') as f:
        for line in f:
            label, char_code = line.strip().split()
            mapping[int(label)] = chr(int(char_code))
    return mapping

# Paths to dataset files
mapping_file = "C:\\Users\\dpand\\Desktop\\New folder\\gzip\\emnist-byclass-mapping.txt"
label_to_char = load_mapping(mapping_file)
train_images = load_images("C:\\Users\\dpand\\Desktop\\New folder\\gzip\\emnist-byclass-train-images-idx3-ubyte.gz")
train_labels = load_labels("C:\\Users\\dpand\\Desktop\\New folder\\gzip\\emnist-byclass-train-labels-idx1-ubyte.gz")

# Preprocess images and labels
train_images = train_images / 255.0
X_train, X_val, y_train, y_val = train_test_split(train_images, train_labels, test_size=0.2, random_state=42)
X_train = X_train.reshape(-1, 28, 28, 1)
X_val = X_val.reshape(-1, 28, 28, 1)

# Data Augmentation
datagen = ImageDataGenerator(
    rotation_range=10,
    width_shift_range=0.1,
    height_shift_range=0.1,
    horizontal_flip=False
)
datagen.fit(X_train)

# Generator Model
def build_generator(latent_dim, num_classes):
    model = Sequential()
    model.add(Dense(128 * 7 * 7, activation="relu", input_dim=latent_dim))
    model.add(Reshape((7, 7, 128)))
    model.add(UpSampling2D())
    model.add(Conv2D(128, kernel_size=3, padding="same"))
    model.add(BatchNormalization(momentum=0.8))
    model.add(LeakyReLU(alpha=0.01))
    model.add(UpSampling2D())
    model.add(Conv2D(64, kernel_size=3, padding="same"))
    model.add(BatchNormalization(momentum=0.8))
    model.add(LeakyReLU(alpha=0.01))
    model.add(Conv2D(1, kernel_size=3, padding="same", activation="tanh"))

    noise = Input(shape=(latent_dim,))
    label = Input(shape=(1,), dtype='int32')
    label_embedding = Flatten()(Embedding(num_classes, latent_dim)(label))
    model_input = multiply([noise, label_embedding])

    img = model(model_input)

    return Model([noise, label], img)

# Discriminator Model
def build_discriminator(img_shape, num_classes):
    model = Sequential()
    model.add(Conv2D(64, kernel_size=3, strides=2, input_shape=(img_shape[0], img_shape[1], img_shape[2] + 1), padding="same"))
    model.add(LeakyReLU(alpha=0.01))
    model.add(Dropout(0.4))
    model.add(Conv2D(128, kernel_size=3, strides=2, padding="same"))
    model.add(LeakyReLU(alpha=0.01))
    model.add(Dropout(0.4))
    model.add(Flatten())
    model.add(Dense(1, activation='sigmoid'))

    # Inputs for image and label
    img = Input(shape=img_shape)
    label = Input(shape=(1,), dtype='int32')
    
    # Embed label and reshape to match image dimensions
    label_embedding = Embedding(num_classes, np.prod(img_shape))(label)
    label_embedding = Flatten()(label_embedding)
    label_embedding = Reshape(img_shape)(label_embedding)

    # Concatenate image and label along the channel axis
    model_input = Concatenate(axis=-1)([img, label_embedding])

    validity = model(model_input)

    return Model([img, label], validity)


# GAN Hyperparameters
img_shape = (28, 28, 1)
latent_dim = 100
num_classes = len(label_to_char)
batch_size = 32
epochs = 1000
save_interval = 100

# ... (rest of your code)

# Build and compile the discriminator
discriminator = build_discriminator(img_shape, num_classes)
discriminator.compile(
    loss='binary_crossentropy',
    optimizer=tf.keras.optimizers.Adam(learning_rate=0.0002, beta_1=0.5),
    metrics=['accuracy']
)

# Build the generator
generator = build_generator(latent_dim, num_classes)

# Combined Model
noise = Input(shape=(latent_dim,))
label = Input(shape=(1,))
img = generator([noise, label])
discriminator.trainable = False
valid = discriminator([img, label])
combined = Model([noise, label], valid)
combined.compile(
    loss='binary_crossentropy',
    optimizer=tf.keras.optimizers.Adam(learning_rate=0.0002, beta_1=0.5)
)

# Training Loop (removed update_state call)
valid = np.ones((batch_size, 1))
fake = np.zeros((batch_size, 1))
d_losses, g_losses = [], []

# ... (rest of the training loop)
def save_imgs(epoch):
    r, c = 5, 5
    noise = np.random.normal(0, 1, (r * c, latent_dim))
    sampled_labels = np.arange(0, num_classes).repeat(r)
    gen_imgs = generator.predict([noise, sampled_labels])
    gen_imgs = 0.5 * gen_imgs + 0.5

    fig, axs = plt.subplots(r, c, figsize=(10, 10))
    cnt = 0
    for i in range(r):
        for j in range(c):
            axs[i, j].imshow(gen_imgs[cnt, :, :, 0], cmap='gray')
            axs[i, j].set_title(f"Label: {sampled_labels[cnt]}")
            axs[i, j].axis('off')
            cnt += 1
    fig.savefig(f"gan_generated_img_{epoch}.png")
    plt.close()

for epoch in range(epochs):
   
    # ---------------------
    #  Train Discriminator
    # ---------------------
    # Select a random batch of real images and their labels
    idx = np.random.randint(0, X_train.shape[0], batch_size)
    imgs, labels = X_train[idx], y_train[idx]
    labels = labels.reshape(-1, 1)  # Ensure labels have shape (batch_size, 1)

    # Generate a batch of fake images
    noise = np.random.normal(0, 1, (batch_size, latent_dim))
    gen_labels = np.random.randint(0, num_classes, batch_size).reshape(-1, 1)  # Correct label shape
    gen_imgs = generator.predict([noise, gen_labels])
    
    discriminator.fit(x=[X_train, y_train], epochs=epochs, batch_size=batch_size)
    combined.fit(x=[noise, gen_labels], epochs=epochs, batch_size=batch_size)

# Train the discriminator
    d_loss_real = discriminator.train_on_batch([imgs, labels], valid)
    d_loss_fake = discriminator.train_on_batch([gen_imgs, gen_labels], fake)
    d_loss = 0.5 * np.add(d_loss_real, d_loss_fake)
    d_losses.append(d_loss[0])  # Track discriminator loss
    

# ---------------------
# Train Generator
# ---------------------
# Generate noise and labels for generator training
    noise = np.random.normal(0, 1, (batch_size, latent_dim))
    gen_labels = np.random.randint(0, num_classes, batch_size).reshape(-1, 1)  # Correct label shape

# Train the generator (wants discriminator to predict "valid" for generated images)
    g_loss = combined.train_on_batch([noise, gen_labels], valid)
    g_losses.append(g_loss)  # Track generator loss

# Print progress
    print(f"{epoch} [D loss: {d_loss[0]} | D acc: {100 * d_loss[1]:.2f}] [G loss: {g_loss}]")

# Save generated images at save intervals
    if epoch % save_interval == 0:
        save_imgs(epoch)


# Plot training losses
plt.plot(d_losses, label='Discriminator Loss')
plt.plot(g_losses, label='Generator Loss')
plt.legend()
plt.title('GAN Training Losses')
plt.xlabel('Epoch')
plt.ylabel('Loss')
plt.show()
# Out:
# C:\Users\dpand\anaconda3\Lib\site-packages\keras\src\models\functional.py:225: UserWarning: The structure of `inputs` doesn't match the expected structure: ['keras_tensor_1684', 'keras_tensor_1685']. Received: the structure of inputs=('*', '*')
#   warnings.warn(
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 450ms/step
# Epoch 1/1000
# C:\Users\dpand\anaconda3\Lib\site-packages\keras\src\models\functional.py:225: UserWarning: The structure of `inputs` doesn't match the expected structure: ['keras_tensor_1610', 'keras_tensor_1611']. Received: the structure of inputs=('*', '*')
#   warnings.warn(
# ---------------------------------------------------------------------------
# ValueError                                Traceback (most recent call last)
# Cell In[32], line 180
#     177     gen_labels = np.random.randint(0, num_classes, batch_size).reshape(-1, 1)  # Correct label shape
#     178     gen_imgs = generator.predict([noise, gen_labels])
# ...

# %%
import gzip
import numpy as np
import matplotlib.pyplot as plt
from sklearn.model_selection import train_test_split
import tensorflow as tf
from tensorflow.keras.models import Sequential
from tensorflow.keras.layers import Conv2D, MaxPooling2D, Flatten, Dense, Input, Dropout
from tensorflow.keras.preprocessing.image import ImageDataGenerator
from tensorflow.keras.callbacks import ReduceLROnPlateau, TensorBoard
import logging
from prometheus_client import start_http_server, Summary, Gauge

def load_images(file_path):
    with gzip.open(file_path, 'rb') as f:
        f.read(16)  
        buffer = f.read()
        data = np.frombuffer(buffer, dtype=np.uint8)
        return data.reshape(-1, 28, 28)

def load_labels(file_path):
    with gzip.open(file_path, 'rb') as f:
        f.read(8)  
        buffer = f.read()
        return np.frombuffer(buffer, dtype=np.uint8)

def load_mapping(mapping_file_path):
    mapping = {}
    with open(mapping_file_path, 'r') as f:
        for line in f:
            label, char_code = line.strip().split()
            mapping[int(label)] = chr(int(char_code))
    return mapping

# Configure logging
logging.basicConfig(filename='model_logs.log', level=logging.INFO, format='%(asctime)s - %(levelname)s - %(message)s')

def log_event(event):
    logging.info(event)

# Prometheus metrics
start_http_server(8000)
REQUEST_TIME = Summary('request_processing_seconds', 'Time spent processing request')
TRAINING_ACCURACY = Gauge('training_accuracy', 'Accuracy of the model during training')
VALIDATION_ACCURACY = Gauge('validation_accuracy', 'Accuracy of the model during validation')

@REQUEST_TIME.time()
def train_model():
    mapping_file = "C:\\Users\\dpand\\Desktop\\New folder\\gzip\\emnist-byclass-mapping.txt"
    label_to_char = load_mapping(mapping_file)

    print("Label 1 corresponds to:", label_to_char[1])

    train_images = load_images("C:\\Users\\dpand\\Desktop\\New folder\\gzip\\emnist-byclass-train-images-idx3-ubyte.gz")
    train_labels = load_labels("C:\\Users\\dpand\\Desktop\\New folder\\gzip\\emnist-byclass-train-labels-idx1-ubyte.gz")

    print("Train images shape:", train_images.shape)
    print("Train labels shape:", train_labels.shape)

    train_images = train_images / 255.0

    X_train, X_val, y_train, y_val = train_test_split(train_images, train_labels, test_size=0.2, random_state=42)
    X_train = X_train.reshape(-1, 28, 28, 1)
    X_val = X_val.reshape(-1, 28, 28, 1)

    datagen = ImageDataGenerator(
        rotation_range=10,
        width_shift_range=0.1,
        height_shift_range=0.1,
        horizontal_flip=False
    )

    datagen.fit(X_train)

    reduce_lr = ReduceLROnPlateau(monitor='val_loss', factor=0.2, patience=2, min_lr=0.001)
    tensorboard_callback = TensorBoard(log_dir='./logs', histogram_freq=1)

    model = Sequential([
        Input(shape=(28, 28, 1)),
        Conv2D(32, (3, 3), activation='relu'),
        MaxPooling2D((2, 2)),
        Conv2D(64, (3, 3), activation='relu'),
        MaxPooling2D((2, 2)),
        Flatten(),
        Dense(64, activation='relu'),
        Dropout(0.3),
        Dense(len(label_to_char), activation='softmax')
    ])

    model.compile(optimizer='adam', loss='sparse_categorical_crossentropy', metrics=['accuracy'])

    train = model.fit(datagen.flow(X_train, y_train, batch_size=32),
                      epochs=10,
                      validation_data=(X_val, y_val),
                      callbacks=[tensorboard_callback, reduce_lr],
                      verbose=1)

    for epoch in range(10):
        TRAINING_ACCURACY.set(train.history['accuracy'][epoch])
        VALIDATION_ACCURACY.set(train.history['val_accuracy'][epoch])
        log_event(f'Epoch {epoch + 1}: Training accuracy: {train.history["accuracy"][epoch]}, Validation accuracy: {train.history["val_accuracy"][epoch]}')

    test_loss, test_accuracy = model.evaluate(X_val, y_val)
    with open("output_log.txt", "w", encoding="utf-8") as f:
        f.write(f"Validation Accuracy = {test_accuracy * 100:.2f}%\n")

    # Plot training & validation accuracy and loss
    plt.figure(figsize=(12, 4))
    plt.subplot(1, 2, 1)
    plt.plot(train.history['accuracy'], label='Train Accuracy')
    plt.plot(train.history['val_accuracy'], label='Validation Accuracy')
    plt.xlabel('Epoch')
    plt.ylabel('Accuracy')
    plt.legend()
    plt.title('Model Accuracy')

    plt.subplot(1, 2, 2)
    plt.plot(train.history['loss'], label='Train Loss')
    plt.plot(train.history['val_loss'], label='Validation Loss')
    plt.xlabel('Epoch')
    plt.ylabel('Loss')
    plt.legend()
    plt.title('Model Loss')

    plt.show()

train_model()
# Out:
# Label 1 corresponds to: 1
# Train images shape: (697932, 28, 28)
# Train labels shape: (697932,)
# C:\Users\dpand\anaconda3\Lib\site-packages\keras\src\trainers\data_adapters\py_dataset_adapter.py:121: UserWarning: Your `PyDataset` class should call `super().__init__(**kwargs)` in its constructor. `**kwargs` can include `workers`, `use_multiprocessing`, `max_queue_size`. Do not pass these arguments to `fit()`, as they will be ignored.
#   self._warn_if_super_not_called()
# Epoch 1/10
# 17449/17449 ━━━━━━━━━━━━━━━━━━━━ 370s 21ms/step - accuracy: 0.6702 - loss: 1.1380 - val_accuracy: 0.8411 - val_loss: 0.4424 - learning_rate: 0.0010
# Epoch 2/10
# 17449/17449 ━━━━━━━━━━━━━━━━━━━━ 392s 22ms/step - accuracy: 0.7997 - loss: 0.5973 - val_accuracy: 0.8461 - val_loss: 0.4344 - learning_rate: 0.0010
# Epoch 3/10
# 17449/17449 ━━━━━━━━━━━━━━━━━━━━ 432s 25ms/step - accuracy: 0.8128 - loss: 0.5555 - val_accuracy: 0.8435 - val_loss: 0.4405 - learning_rate: 0.0010
# Epoch 4/10
# ...
